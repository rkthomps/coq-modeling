# %%
import os
import random
import sklearn
import matplotlib.pyplot as plt
import sklearn.manifold
#import sklearn.decomposition
from premise_selection.premise_vector_db import PremiseVectorDB
from data_management.sentence_db import SentenceDB

# %%
os.chdir(os.path.join(os.environ["HOME"], "coq-modeling"))

# %%
sentence_db = SentenceDB.load("sentences.db")
vector_db = PremiseVectorDB.load("vector-dbs/prem-select")

# %%
idx_sample = random.sample(range(500000), 1000)

# %%
sentences = [sentence_db.retrieve(i) for i in idx_sample]
embeddings = vector_db.get_embs(idx_sample)

# %%
pca = sklearn.manifold.TSNE()
new = pca.fit_transform(embeddings)

# %%
pca.explained_variance_
# Out:
# array([0.06672437, 0.04641502])

# %%
fig, ax = plt.subplots()
ax.scatter(new[:, 0], new[:, 1])
